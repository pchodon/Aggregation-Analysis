# %% [markdown]
# <a href="https://colab.research.google.com/github/pchodon/Aggregation-Analysis/blob/main/basic4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import multiprocessing
import time
from csv import reader
from google.colab import files
import pandas as pd
import threading
import os
import tensorflow as tf
import numpy as np
import sys
import matplotlib.pyplot as plt
  
data = []
with open('/content/drive/MyDrive/Bias_correction_ucl.csv', 'r',encoding="ISO-8859-1") as data:
  df_weather = pd.read_csv(data, parse_dates=["Date"])

df_grp = (df_weather.groupby(['station']).groups)

outcome = df_weather.set_index("station")
outcome_date = outcome.set_index("Date")
outcome_na = outcome_date[~(outcome_date == 0).all(axis=1)]
outcome_final = outcome_date.resample('D').sum()
display(outcome_na)
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30          28.7          21.4    58.255688    91.116364
# 2013-06-30          31.9          21.6    52.263397    90.604721
# 2013-06-30          31.6          23.3    48.690479    83.973587
# 2013-06-30          32.0          23.4    58.239788    96.483688
# 2013-06-30          31.4          21.9    56.174095    90.155128
# 2013-06-30          31.9          23.5    52.437126    85.307251
# 2013-06-30          31.4          24.4    56.287189    81.019760
# 2013-06-30          32.1          23.6    52.326218    78.004539
# 2013-06-30          31.4          22.0    55.338791    80.784607
# 2013-06-30          31.6          20.5    56.651203    86.849632
# 2013-06-30          31.7          23.5    51.156395    85.385635
# 2013-06-30          31.6          22.2    51.288349    80.338013
# 2013-06-30          32.1          23.8    48.767929    84.008163
# ...
